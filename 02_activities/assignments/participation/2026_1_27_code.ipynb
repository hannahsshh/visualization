# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

np.random.seed(123)
x = np.arange(50)
y1 = np.random.randint(0,100,50)
y2 = np.random.randint(0,100,50)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

plt.xticks(rotation=45, ha='right') #rotates the x axis labels

ax.set_xlabel('New X axis!',fontsize=18)

fig.show()
# Out:
# /var/folders/pb/1_jy3__90dx87vmmj5l54lbr0000gn/T/ipykernel_88517/2910687047.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

plt.xticks(rotation=45, ha='right') 

font1 = {'family':'serif','color':'indigo'}

ax.set_xlabel('New X axis!',fontsize=18, fontdict=font1)

fig.show()
# Out:
# /var/folders/pb/1_jy3__90dx87vmmj5l54lbr0000gn/T/ipykernel_88517/1902020055.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

plt.xticks(rotation=45, ha='right') 

font1 = {'family':'serif','color':'indigo'}

#ax.set_xlabel('New X axis!',fontsize=18, fontdict=font1)

plt.xlabel('New X axis!',fontsize=18, fontdict=font1)

fig.show()
# Out:
# /var/folders/pb/1_jy3__90dx87vmmj5l54lbr0000gn/T/ipykernel_88517/1157744077.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
plt.style.use('fivethirtyeight')

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0,100,50)
y2 = np.random.randint(0,100,50)

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# /var/folders/pb/1_jy3__90dx87vmmj5l54lbr0000gn/T/ipykernel_88517/600854812.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
np.random.seed(613)

x1 = np.arange(50)
y1 = np.random.randint(0,75,50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2 = np.array([110, 180, 240, 99, 220])

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2,
                               nrows=1,
                               figsize=(7,3))

ax1.scatter(x1,y1)
ax2.bar(x2,y2)

fig.show()
# Out:
# /var/folders/pb/1_jy3__90dx87vmmj5l54lbr0000gn/T/ipykernel_88517/3491023872.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2,
                               nrows=1,
                               figsize=(7,3))

ax1.scatter(x1,y1)
ax1.annotate('This is important', xy=(10,65),xytext=(30,65),arrowprops=dict(facecolor='black'))
ax2.bar(x2,y2)

fig.show()
# Out:
# /var/folders/pb/1_jy3__90dx87vmmj5l54lbr0000gn/T/ipykernel_88517/1879485418.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, someaxes = plt.subplot_mosaic([['ax1','ax3'],
                                    ['ax2','ax3']],
                                    figsize=(7,4))

someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

# %%
fig, someaxes = plt.subplot_mosaic([['ax1','ax3'],
                                    ['ax2','ax3']],
                                    figsize=(7,4))

someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
someaxes["ax1"].set_xlabel('A big label',fontsize=18)
someaxes["ax2"].set_xlabel('Another label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 fast 2 furious',fontsize=18)
# Out:
# Text(0.5, 0, 'Label 2: 2 fast 2 furious')

# %%
fig, someaxes = plt.subplot_mosaic([['ax1','ax3'],
                                    ['ax2','ax3']],
                                    figsize=(7,4),
                                    layout="tight")

someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
someaxes["ax1"].set_xlabel('A big label',fontsize=18)
someaxes["ax2"].set_xlabel('Another label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 fast 2 furious',fontsize=18)
# Out:
# Text(0.5, 0, 'Label 2: 2 fast 2 furious')

# %%
fig, someaxes = plt.subplot_mosaic([['ax1','ax3'],
                                    ['ax2','ax3']],
                                    figsize=(7,4),
                                    layout="constrained")

someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
someaxes["ax1"].set_xlabel('A big label',fontsize=18)
someaxes["ax2"].set_xlabel('Another label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 fast 2 furious',fontsize=18)
# Out:
# Text(0.5, 0, 'Label 2: 2 fast 2 furious')

# %%
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])

fig, ax = plt.subplots(figsize=(7,3))

ax.bar(x, y1,
       color="indigo")
ax.plot(x, y2,
        color="red")

# %%
y2_sd = np.std(y2)
fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x, y2, color="blue")
ax.errorbar(x,
            y2,
            color="red",
            yerr = y2_sd,
            fmt="none")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x, y2, color="red")
ax.errorbar(x,
            y2,
            yerr = y2_sd,
            fmt="none",
            ecolor="indigo",
            elinewidth=4,
            capsize=6,
            capthick=4)
# Out:
# <ErrorbarContainer object of 3 artists>
